# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeNana23/colab-git-assignment2-AN-/blob/feature-branch/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "AngeNana23"
# !git config --global user.email "ange.nana@students.williscollege.com"

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=AngeNana23
# user.email=ange.nana@students.williscollege.com

# %%
# !git clone https://AngeNana23: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@github.com/AngeNana23/colab-git-assignment2-AN-.git
# Out:
# Cloning into 'colab-git-assignment2-AN-'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 26 (delta 7), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 12.40 KiB | 12.40 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd colab-git-assignment2-AN-
# Out:
# /content/colab-git-assignment2-AN-

# %%
# !ls
# Out:
# README.md

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %%
# !git add assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# [main b30a739] Add initial notebook with multiplication function
#  1 file changed, 1 insertion(+)
#  create mode 100644 assignment2.ipynb

# %%
from getpass import getpass
token = getpass("Enter GitHub PAT: ")

# !git remote set-url origin https://AngeNana23:{token}@github.com/AngeNana23/colab-git-assignment2-AN-.git
# !git push -u origin main
# Out:
# Enter GitHub PAT: ··········
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date

# %%
# !git checkout -b feature-branch
# Out:
# fatal: A branch named 'feature-branch' already exists.

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"
print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
# !git add assignment2.ipynb
# !git rebase --continue
# !git push --set-upstream origin feature-branch
# Out:
# fatal: No rebase in progress?
# Branch 'feature-branch' set up to track remote branch 'feature-branch' from 'origin'.
# Everything up-to-date

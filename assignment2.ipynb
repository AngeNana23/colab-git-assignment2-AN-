# %%
!
# !apt-get install -y git
# Configure Git (replace with your details)
# !git config --global user.email "ange.nana@students.williscollege.com"
# !git config --global user.name "AngeNana23"
print("Git configured successfully")

# %%
import os

target_dir = f"/content/{repo_name}"

# Ensure we are in the correct directory.
os.chdir(target_dir)

print(f"Current working directory: {os.getcwd()}")
# !ls

# %%
# !git clone https://github.com/AngeNana23/-colab-git-assignment2--AN-
# %cd -colab-git-assignment2--AN-
# !ls

# %%
# !git clone https://github.com/AngeNana23/-colab-git-assignment2--AN-
# %cd -colab-git-assignment2--AN-

# %%
import os

repo_name = "-colab-git-assignment2--AN-"
repo_url = f"https://github.com/AngeNana23/{repo_name}"
target_dir = f"/content/{repo_name}"

# Check if the directory exists and remove it to ensure a clean clone
if os.path.exists(target_dir):
    print(f"Removing existing directory: {target_dir}")
    # !rm -rf {target_dir}

# Clone the repository
# !git clone {repo_url}

# Change into the cloned directory
os.chdir(target_dir)

print(f"Current working directory: {os.getcwd()}")
# !ls

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))

# %%
# !git add assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"

# %%
import os

repo_name = "-colab-git-assignment2--AN-"
repo_url = f"https://github.com/AngeNana23/{repo_name}"
target_dir = f"/content/{repo_name}"

# Check if the directory exists and remove it to ensure a clean clone
if os.path.exists(target_dir):
    print(f"Removing existing directory: {target_dir}")
    # !rm -rf {target_dir}

# Clone the repository
# !git clone {repo_url}

# Change into the cloned directory
os.chdir(target_dir)

print(f"Current working directory: {os.getcwd()}")
# !ls

# %%
# Save the current notebook to be tracked by Git
# %notebook -e assignment2.ipynb

# !git add assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"

# %%
import os

repo_name = "-colab-git-assignment2--AN-"
repo_url = f"https://github.com/AngeNana23/{repo_name}"
target_dir = f"/content/{repo_name}"

# Ensure we are in a safe directory before any operations
os.chdir("/content")

# Check if the directory exists and remove it to ensure a clean clone
if os.path.exists(target_dir):
    print(f"Removing existing directory: {target_dir}")
    # !rm -rf {target_dir}

# Clone the repository
# !git clone {repo_url}

# Change into the cloned directory only if clone was successful
if os.path.exists(target_dir):
    os.chdir(target_dir)
    print(f"Current working directory: {os.getcwd()}")
    # !ls
else:
    print(f"Error: Repository was not cloned successfully into {target_dir}")
